# %%
import numpy as np

# %%
np.random.seed(1)

# %%
x = np.random.randint(0, 50, 1000)

# %%
x
# Out:
# array([37, 43, 12,  8,  9, 11,  5, 15,  0, 16,  1, 12,  7, 45,  6, 25, 20,
#        37, 18, 20, 11, 42, 28, 29, 14,  4, 23, 23, 41, 49, 30, 32, 22, 13,
#        41,  9,  7, 22,  1,  0, 17,  8, 24, 13, 47, 42,  8, 30,  7,  3,  6,
#        21, 49,  3,  4, 24, 49, 43, 12, 26, 16, 45, 41, 18, 15,  0,  4, 25,
#        47, 34, 23,  7, 26, 25, 40, 22,  9,  3, 39, 23, 36, 27, 37, 19, 38,
#         8, 32, 34, 10, 23, 15, 47, 23, 25,  7, 28, 10, 46, 32, 24, 23,  1,
#        49, 13,  3,  0, 13,  6, 21,  6,  2, 12, 27, 21, 11,  7, 13,  8, 11,
#        12, 43, 20, 30, 36, 39,  7, 45,  4, 48, 18, 32, 13, 10, 23, 17,  7,
#        24, 10, 28, 20, 32, 12,  1, 30, 41, 24, 18, 33,  2, 44, 28, 39, 34,
#        10, 32, 41, 18, 22,  6,  2,  7, 39, 48, 15,  5, 17, 42, 20, 48, 22,
#        37, 13, 49, 33, 20, 10, 32, 25, 21, 39, 32, 19, 25, 49, 14, 13, 20,
#        43,  6, 13, 15, 24,  9,  2,  7,  5, 36, 37, 21, 40, 13, 27, 49, 49,
# ...

# %%
#positive correlation with some noise
y = x + np.random.normal(0, 10, 1000)

# %%
y
# Out:
# array([ 2.76598838e+01,  4.01817810e+01, -3.60843547e+00,  9.97843587e+00,
#         1.68498577e+01,  2.24382038e+01, -1.91368213e+00,  2.21240798e+01,
#        -2.30015293e-01,  1.10094560e+01,  7.52919655e+00, -8.67173888e+00,
#         1.80503131e+01,  5.09361343e+01,  8.04058494e+00,  3.66973816e+01,
#         7.40255092e+00,  4.09996783e+01,  1.24515886e+01,  1.56100385e+01,
#         2.33701150e+00,  3.92722209e+01,  5.05580491e+01,  3.08363536e+01,
#         1.05751126e+01, -4.30455594e+00,  2.34633515e+01,  1.52720965e+01,
#         5.30015121e+01,  6.46202567e+01,  2.42740746e+01,  3.87963852e+01,
#         6.87810647e+00,  2.20638526e+01,  3.83716440e+01,  3.44966082e+00,
#         1.90045465e+00,  2.49067168e+01, -5.08385133e+00,  1.17800686e+01,
#         1.69033804e+01,  1.68288956e+01,  2.08079590e+01,  1.72568060e+01,
#         3.29970894e+01,  2.80344601e+01,  5.15792898e+00,  2.32244063e+01,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81408886],
#        [0.81408886, 1.        ]])

# %%
from io import IncrementalNewlineDecoder
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
y =  np.random.normal(0, 10, 1000) - x

# %%
y
# Out:
# array([-4.88570811e+01, -4.12962255e+01, -1.56163044e+01, -1.13708551e+01,
#        -2.02910551e+01,  4.81708913e+00, -8.34195827e+00, -1.80217884e+00,
#        -7.28011633e+00,  2.02819625e+00, -3.19869121e+00, -2.02090127e+01,
#        -3.82995388e+01, -4.27330310e+01, -1.19442266e+01, -2.03002722e+01,
#        -3.15256534e+01, -3.66770569e+01, -2.16772779e+01, -3.26776541e+01,
#        -9.00953783e+00, -5.33095638e+01, -2.11653520e+01, -2.96920992e+01,
#        -2.10438290e+01, -9.82760201e-01, -3.67172599e+01, -4.55894642e+00,
#        -1.94039634e+01, -4.89124029e+01, -3.49858433e+01, -4.31554813e+01,
#         1.79746511e+00, -1.70677735e+01, -4.07620356e+01, -2.73993436e+01,
#        -1.56972683e+00, -3.86122051e+01,  8.77043012e+00, -4.54327162e+00,
#        -7.40213401e+00, -2.35555465e+00, -2.74851996e+01, -1.68278182e+01,
#        -5.40750966e+01, -4.13129024e+01, -2.83260944e+01, -2.52831287e+01,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.80901668],
#        [-0.80901668,  1.        ]])

# %%
from io import IncrementalNewlineDecoder
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
#1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

#negative correlation with some noise
y = 100 - x + np.random.normal(0, 5, 1000)

np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.94615861],
#        [-0.94615861,  1.        ]])

# %%
x = np.random.randint(0, 50, 1000)
y = np.random.randint(0, 50, 1000)

np.corrcoef(x,y)
# Out:
# array([[1.        , 0.02870485],
#        [0.02870485, 1.        ]])

# %%
from io import IncrementalNewlineDecoder
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'a':np.random.randint(0, 50, 1000)})
df['b'] = df['a'] + np.random.normal(0, 10, 1000) # positive correlation
df['c']= 100 - df['a'] + np.random.normal(0, 5, 1000)#negatively correlation 
df['d'] = np.random.randint(0, 50, 1000)#not correlated with 'a'

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.819319 -0.949277 -0.033036
# b  0.819319  1.000000 -0.778370 -0.025267
# c -0.949277 -0.778370  1.000000  0.048537
# d -0.033036 -0.025267  0.048537  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
